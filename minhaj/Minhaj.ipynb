# %%
ch=int(input("Enter your choice:\n1.Addition\n2.Subtraction\n3.Multiplication\n4.Division"))
a=int(input("Enter First Number:"))
b=int(input("Enter second number:"))
if(ch==1):
    print("Sum=",a+b)
elif(ch==2):
    print("Difference",a-b)
elif(ch==3):
    print("Multiplication",a*b)
elif(ch==4):
    print("Division",a/b)
else:
    print("Invaliid input")
# Out:
# Enter your choice:
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division5
# Enter First Number:2
# Enter second number:2
# Invaliid input

# %%
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
print("AND",a and b)
print("OR",a or b)
print("NOT",not a)
print("a<b",a<b)
print("a>b",a>b)
print("a<=b",a<=b)
print("a>=b",a>=b)
print("a==b",a==b)
print("a!=b",a!=b)
# Out:
# Enter first number:1
# Enter second number:1
# AND 1
# OR 1
# NOT False
# a<b False
# a>b False
# a<=b True
# a>=b True
# a==b True
# a!=b False

# %%
a={"Roll no":15,"Name":"Dilshad"}
b={"Place":"Mavoor","No":12345678}
c={"Roll no":15,"Name":"Minhaj"}
a.update(b)
a.update(c)
print(a)
# Out:
# {'Roll no': 15, 'Name': 'Minhaj', 'Place': 'Mavoor', 'No': 12345678}

# %%
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
c=int(input("Enter third number:"))
if(a>b and a>c):
    print("First num is largest!")
elif(b>a and b>c):
    print("Second num is largest!")
elif(c>a and c>b):
    print("Third num is largest!")
# Out:
# Enter first number:1
# Enter second number:4
# Enter third number:2
# Second num is largest!

# %%
list1=[1,2,3,4]
list1.append(4)
list1.insert(2,3)
list1.remove(3)
list1.pop(3)
list2=list1.copy()
print(list2)
# Out:
# [1, 2, 3, 4]
